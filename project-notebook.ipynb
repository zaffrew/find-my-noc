# %% [markdown]
# # Find my NOC
#
# ### The goal of this notebook is to map job postings to their correct job code (NOC)

# %%
# utils
import pandas as pd
import numpy as np

# modules
import src.utils.data_cleaning as data_cleaning
import models.demand.demand as demand

# %% [markdown]
# ### Import relevant datasets
# First, let's import all of the postings that are obtained from the external MySQL database beforehand. I have already downloaded the data dump from the database to save time. The data in the MySQL database has been aggregated from different job posting websites. This database is designed for a different project by an external organization and I have special access to it for this project.

# %%
postings = pd.read_csv('data/raw/postings.csv')

# %%
postings.head()
# Out:
#                                hash  \
# 0  000007c5b6113eafb89b3b73c811dfb4
# 1  00000be8f81af54b07c885688edb14db
# 2  00001627d6d70611a25853337fb5912b
# 3  000058401cec51520f401a493886e5f5
# 4  000066567c6fe57b54b79cb41ff4e03a
#
#                                           title  \
# 0           FINANCIAL ANALYST  Corporate Office
# 1                                Security Guard
# 2      Kitchen Exhaust Hood Cleaning Technician
# 3                 Child Care Supply / Assistant
# 4  WINDSOR &#8211; Sales Team Member: Part Time
#
#                                              content   noc
# 0                                                NaN  1112
# 1  Retail environment. Ensuring COVID19 restricti...  6541
# 2  Hood Cleaners of America is looking for candid...  6732
# 3  Good Shepherd Lutheran Christian Day Care is l...  4214
# 4  Princess Auto is a Canadian based multi-channe...  6421

# %%
postings.size
# Out:
# 1256728

# %%
postings.noc.value_counts()
# Out:
# 6421    16235
# 7452    15981
# 4412    12497
# 6552    11801
# 7511    10294
#         ...
# 8614        1
# 8441        1
# 1227        1
# 2146        1
# 5245        1
# Name: noc, Length: 519, dtype: int64

# %% [markdown]
# Out of all the postings, only some are human labelled. The rest are labelled by a string-matching program that does not make use of machine learning. We will train the model on the human-labelled data.

# %%
jobs_to_tags = pd.read_csv('data/raw/jobs_to_tags.csv')

# %%
jobs_to_tags.head()
# Out:
#                                hash
# 0  0000773cb4875c8a442094365013263f
# 1  0001990412714e43f413d6b37b13a166
# 2  000d1e8051337e97660c0052379d9b0a
# 3  001a4de013ee3c8ba2f36c5bce851dbe
# 4  001af489878da488b65b079afe993c82

# %% [markdown]
# These hashes correspond to those job postings that are hand matched.
#
# Now, we can filter rows from postings that also fall in jobs_to_tags.

# %%
human_labelled_postings = pd.merge(postings,
                        jobs_to_tags,
                        on='hash',
                        how='inner')

# %%
human_labelled_postings.size
# Out:
# 35288

# %%
human_labelled_postings.to_csv('data/interim/human_labelled_postings.csv')

# %% [markdown]
# ### Data Cleaning

# %%
cleaned_postings = data_cleaning.run(input_file='data/interim/human_labelled_postings.csv', output_file='data/cleaned/cleaned_postings.csv')

# %%
cleaned_postings.head()
# Out:
#                                hash  \
# 0  0000773cb4875c8a442094365013263f
# 1  0001990412714e43f413d6b37b13a166
# 2  000d1e8051337e97660c0052379d9b0a
# 3  001a4de013ee3c8ba2f36c5bce851dbe
# 4  001af489878da488b65b079afe993c82
#
#                                              content   noc
# 0  housekeep aid clean assign hospit manner candi...  3414
# 1  summer summari cream manufactur outgrow commun...  9617
# 2  adjoint bureau emplac provinc type classif rel...  1511
# 3  develop manag market descript univers student ...  0213
# 4  covid test site grow fit duti prioriti safeti ...  3414

# %%
cleaned_postings.isna().sum()
# Out:
# hash       0
# content    0
# noc        0
# dtype: int64

# %% [markdown]
# By the end of this step, we have fully pre-processed text. I have only considered nouns and verbs as these would provide the most meaning and also help in saving time and space.

# %% [markdown]
# ### Prediction of classes
# The NOC has a tree stucture. It would be difficult to directly classify a job posting to a 4 digit NOC. We can take advantage of the the tree structure by making predictions for each level. To start with, the top level only has 10 classes (0 - 9). We can classify each job posting to one of these 10 classes and then we will be left with 10 partitions. Within each partition, we will need to make predictions for the second-, third-, and fourth-level.
#
# For training purposes, we will train on the top level first using the first digit of the NOC. We will then partition the data according to the label and now train on the second digit.
#
# This function is written in the demand.py file.

# %%
level_3_df = demand.traversal(cleaned_postings) 
# traversal does not change the data itself, it just adds columns corresponding to each level of the NOC and is a
# way to test if the concatenation is working or not
# Out:
# Training model...
# Created pipeline
# Fitted
# Model: class_top_level_0, Train Accuracy: 73.95104895104895%, Test Accuracy: 63.58436606291706%
# Training model...
# Created pipeline
# Fitted
# Model: class_3_level_1, Train Accuracy: 88.70523415977961%, Test Accuracy: 67.21311475409836%
# Training model...
# Created pipeline
# Fitted
# Model: class_9_level_1, Train Accuracy: 59.210526315789465%, Test Accuracy: 58.77192982456141%
# Training model...
# Created pipeline
# Fitted
# Model: class_1_level_1, Train Accuracy: 84.67650397275823%, Test Accuracy: 65.3061224489796%
# Training model...
# Created pipeline
# Fitted
# Model: class_0_level_1, Train Accuracy: 88.88888888888889%, Test Accuracy: 63.31360946745562%
# Training model...
# Created pipeline
# Fitted
# Model: class_8_level_1, Train Accuracy: 58.46153846153847%, Test Accuracy: 54.54545454545454%
# Training model...
# Created pipeline
# Fitted
# Model: class_6_level_1, Train Accuracy: 79.06793048973144%, Test Accuracy: 56.73758865248227%
# Training model...
# Created pipeline
# Fitted
# Model: class_7_level_1, Train Accuracy: 84.97011101622545%, Test Accuracy: 63.171355498721226%
# Training model...
# Created pipeline
# Fitted
# Model: class_2_level_1, Train Accuracy: 87.59689922480621%, Test Accuracy: 68.02325581395348%
# Training model...
# Created pipeline
# Fitted
# Model: class_4_level_1, Train Accuracy: 82.0754716981132%, Test Accuracy: 67.13615023474179%
# Training model...
# Created pipeline
# Fitted
# Model: class_5_level_1, Train Accuracy: 84.72222222222221%, Test Accuracy: 83.33333333333334%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_32_level_2, Train Accuracy: 83.33333333333334%, Test Accuracy: 78.57142857142857%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_31_level_2, Train Accuracy: 98.0392156862745%, Test Accuracy: 77.77777777777779%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_94_level_2, Train Accuracy: 85.2112676056338%, Test Accuracy: 77.08333333333334%
# Training model...
# Created pipeline
# Fitted
# Model: class_95_level_2, Train Accuracy: 95.55555555555556%, Test Accuracy: 50.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_92_level_2, Train Accuracy: 85.1063829787234%, Test Accuracy: 56.25%
# Training model...
# Created pipeline
# Fitted
# Model: class_15_level_2, Train Accuracy: 90.5982905982906%, Test Accuracy: 84.61538461538461%
# Training model...
# Created pipeline
# Fitted
# Model: class_11_level_2, Train Accuracy: 94.40298507462687%, Test Accuracy: 88.88888888888889%
# Training model...
# Created pipeline
# Fitted
# Model: class_14_level_2, Train Accuracy: 56.94444444444444%, Test Accuracy: 62.5%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_12_level_2, Train Accuracy: 82.37179487179486%, Test Accuracy: 70.1923076923077%
# Training model...
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_06_level_2, Train Accuracy: 92.17391304347827%, Test Accuracy: 66.66666666666666%
# Training model...
# Created pipeline
# Fitted
# Model: class_01_level_2, Train Accuracy: 58.333333333333336%, Test Accuracy: 65.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_08_level_2, Train Accuracy: 92.85714285714286%, Test Accuracy: 80.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_04_level_2, Train Accuracy: 81.66666666666667%, Test Accuracy: 80.0%
# Training model...
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_07_level_2, Train Accuracy: 91.66666666666666%, Test Accuracy: 91.66666666666666%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_84_level_2, Train Accuracy: 94.33962264150944%, Test Accuracy: 94.44444444444444%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_82_level_2, Train Accuracy: 90.0%, Test Accuracy: 90.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_67_level_2, Train Accuracy: 84.04558404558404%, Test Accuracy: 84.7457627118644%
# Training model...
# Created pipeline
# Fitted
# Model: class_64_level_2, Train Accuracy: 87.37201365187714%, Test Accuracy: 83.6734693877551%
# Training model...
# Created pipeline
# Fitted
# Model: class_63_level_2, Train Accuracy: 61.458333333333336%, Test Accuracy: 56.25%
# Training model...
# Created pipeline
# Fitted
# Model: class_65_level_2, Train Accuracy: 57.67790262172284%, Test Accuracy: 55.0561797752809%
# Training model...
# Created pipeline
# Fitted
# Model: class_66_level_2, Train Accuracy: 94.0%, Test Accuracy: 92.15686274509804%
# Training model...
# Created pipeline
# Fitted
# Model: class_62_level_2, Train Accuracy: 57.407407407407405%, Test Accuracy: 47.22222222222222%
# Training model...
# Created pipeline
# Fitted
# Model: class_75_level_2, Train Accuracy: 78.10457516339869%, Test Accuracy: 79.41176470588235%
# Training model...
# Created pipeline
# Fitted
# Model: class_74_level_2, Train Accuracy: 91.5%, Test Accuracy: 83.5820895522388%
# Training model...
# Created pipeline
# Fitted
# Model: class_72_level_2, Train Accuracy: 94.79553903345726%, Test Accuracy: 61.111111111111114%
# Training model...
# Created pipeline
# Fitted
# Model: class_73_level_2, Train Accuracy: 89.5104895104895%, Test Accuracy: 60.416666666666664%
# Training model...
# Created pipeline
# Fitted
# Model: class_76_level_2, Train Accuracy: 88.09523809523809%, Test Accuracy: 84.70588235294117%
# Training model...
# Created pipeline
# Fitted
# Model: class_21_level_2, Train Accuracy: 86.1244019138756%, Test Accuracy: 65.71428571428571%
# Training model...
# Created pipeline
# Fitted
# Model: class_22_level_2, Train Accuracy: 92.81045751633987%, Test Accuracy: 66.01941747572816%
# Training model...
# Created pipeline
# Fitted
# Model: class_41_level_2, Train Accuracy: 95.55555555555556%, Test Accuracy: 84.21052631578947%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_44_level_2, Train Accuracy: 95.45454545454545%, Test Accuracy: 94.5945945945946%
# Training model...
# Created pipeline
# Fitted
# Model: class_40_level_2, Train Accuracy: 80.73394495412845%, Test Accuracy: 83.78378378378379%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_52_level_2, Train Accuracy: 50.877192982456144%, Test Accuracy: 60.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_51_level_2, Train Accuracy: 64.28571428571429%, Test Accuracy: 40.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_341_level_3, Train Accuracy: 73.64341085271317%, Test Accuracy: 60.46511627906976%
# Training model...
# Created pipeline
# Fitted
# Model: class_323_level_3, Train Accuracy: 72.41379310344827%, Test Accuracy: 75.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_321_level_3, Train Accuracy: 96.875%, Test Accuracy: 63.63636363636363%
# Training model...
# Created pipeline
# Fitted
# Model: class_322_level_3, Train Accuracy: 66.66666666666666%, Test Accuracy: 0.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_301_level_3, Train Accuracy: 71.9298245614035%, Test Accuracy: 78.94736842105263%
# Training model...
# Created pipeline
# Fitted
# Model: class_314_level_3, Train Accuracy: 52.63157894736842%, Test Accuracy: 28.57142857142857%
# Training model...
# Created pipeline
# Fitted
# Model: class_311_level_3, Train Accuracy: 66.66666666666666%, Test Accuracy: 0.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_313_level_3, Train Accuracy: 100.0%, Test Accuracy: 100.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_312_level_3, Train Accuracy: 60.0%, Test Accuracy: 100.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_961_level_3, Train Accuracy: 74.00990099009901%, Test Accuracy: 71.11111111111111%
# Training model...
# Created pipeline
# Fitted
# Model: class_943_level_3, Train Accuracy: 61.904761904761905%, Test Accuracy: 85.71428571428571%
# Training model...
# Created pipeline
# Fitted
# Model: class_941_level_3, Train Accuracy: 98.4375%, Test Accuracy: 31.818181818181817%
# Training model...
# Created pipeline
# Fitted
# Model: class_942_level_3, Train Accuracy: 83.33333333333334%, Test Accuracy: 88.88888888888889%
# Training model...
# Created pipeline
# Fitted
# Model: class_946_level_3, Train Accuracy: 80.76923076923077%, Test Accuracy: 77.77777777777779%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_947_level_3, Train Accuracy: 66.66666666666666%, Test Accuracy: 50.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_953_level_3, Train Accuracy: 50.0%, Test Accuracy: 31.25%
# Training model...
# Created pipeline
# Fitted
# Model: class_952_level_3, Train Accuracy: 46.51162790697674%, Test Accuracy: 40.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_924_level_3, Train Accuracy: 72.22222222222221%, Test Accuracy: 100.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_921_level_3, Train Accuracy: 83.33333333333334%, Test Accuracy: 71.42857142857143%
# Training model...
# Created pipeline
# Fitted
# Model: class_922_level_3, Train Accuracy: 77.77777777777779%, Test Accuracy: 66.66666666666666%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_151_level_3, Train Accuracy: 85.71428571428571%, Test Accuracy: 62.5%
# Training model...
# Created pipeline
# Fitted
# Model: class_152_level_3, Train Accuracy: 98.94736842105263%, Test Accuracy: 31.25%
# Training model...
# Created pipeline
# Fitted
# Model: class_112_level_3, Train Accuracy: 56.29139072847682%, Test Accuracy: 58.82352941176471%
# Training model...
# Created pipeline
# Fitted
# Model: class_111_level_3, Train Accuracy: 82.05128205128204%, Test Accuracy: 71.7948717948718%
# Training model...
# Created pipeline
# Fitted
# Model: class_141_level_3, Train Accuracy: 48.888888888888886%, Test Accuracy: 37.5%
# Training model...
# Created pipeline
# Fitted
# Model: class_143_level_3, Train Accuracy: 94.04761904761905%, Test Accuracy: 89.28571428571429%
# Training model...
# Created pipeline
# Fitted
# Model: class_145_level_3, Train Accuracy: 66.66666666666666%, Test Accuracy: 100.0%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_131_level_3, Train Accuracy: 66.66666666666666%, Test Accuracy: 85.71428571428571%
# Training model...
# Created pipeline
# Fitted
# Model: class_122_level_3, Train Accuracy: 67.79661016949152%, Test Accuracy: 72.5%
# Training model...
# Created pipeline
# Fitted
# Model: class_124_level_3, Train Accuracy: 60.99290780141844%, Test Accuracy: 57.446808510638306%
# Training model...
# Created pipeline
# Fitted
# Model: class_125_level_3, Train Accuracy: 75.0%, Test Accuracy: 100.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_121_level_3, Train Accuracy: 72.72727272727273%, Test Accuracy: 80.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_021_level_3, Train Accuracy: 66.66666666666666%, Test Accuracy: 30.0%
# Training model...
# Training model...
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_063_level_3, Train Accuracy: 91.66666666666666%, Test Accuracy: 83.33333333333334%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_011_level_3, Train Accuracy: 53.48837209302325%, Test Accuracy: 53.333333333333336%
# Training model...
# Created pipeline
# Fitted
# Model: class_012_level_3, Train Accuracy: 51.388888888888886%, Test Accuracy: 37.5%
# Training model...
# Created pipeline
# Fitted
# Model: class_013_level_3, Train Accuracy: 75.0%, Test Accuracy: 100.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_082_level_3, Train Accuracy: 91.66666666666666%, Test Accuracy: 100.0%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_041_level_3, Train Accuracy: 50.0%, Test Accuracy: 25.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_042_level_3, Train Accuracy: 66.66666666666666%, Test Accuracy: 52.94117647058824%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_001_level_3, Train Accuracy: 43.47826086956522%, Test Accuracy: 62.5%
# Training model...
# Created pipeline
# Fitted
# Model: class_051_level_3, Train Accuracy: 87.5%, Test Accuracy: 100.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_071_level_3, Train Accuracy: 92.42424242424242%, Test Accuracy: 72.72727272727273%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_091_level_3, Train Accuracy: 93.75%, Test Accuracy: 100.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_843_level_3, Train Accuracy: 98.0%, Test Accuracy: 64.70588235294117%
# Training model...
# Created pipeline
# Fitted
# Model: class_842_level_3, Train Accuracy: 100.0%, Test Accuracy: 0.0%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_861_level_3, Train Accuracy: 91.96428571428571%, Test Accuracy: 97.36842105263158%
# Training model...
# Created pipeline
# Fitted
# Model: class_825_level_3, Train Accuracy: 77.77777777777779%, Test Accuracy: 77.77777777777779%
# Training model...
# Training model...
# Training model...
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_673_level_3, Train Accuracy: 78.84615384615384%, Test Accuracy: 69.81132075471697%
# Training model...
# Created pipeline
# Fitted
# Model: class_672_level_3, Train Accuracy: 73.33333333333333%, Test Accuracy: 80.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_674_level_3, Train Accuracy: 70.0%, Test Accuracy: 100.0%
# Training model...
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_631_level_3, Train Accuracy: 73.68421052631578%, Test Accuracy: 40.0%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_632_level_3, Train Accuracy: 94.44444444444444%, Test Accuracy: 83.33333333333334%
# Training model...
# Created pipeline
# Fitted
# Model: class_634_level_3, Train Accuracy: 88.88888888888889%, Test Accuracy: 66.66666666666666%
# Training model...
# Created pipeline
# Fitted
# Model: class_651_level_3, Train Accuracy: 84.375%, Test Accuracy: 81.81818181818183%
# Training model...
# Created pipeline
# Fitted
# Model: class_652_level_3, Train Accuracy: 78.94736842105263%, Test Accuracy: 85.71428571428571%
# Training model...
# Created pipeline
# Fitted
# Model: class_653_level_3, Train Accuracy: 66.66666666666666%, Test Accuracy: 0.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_655_level_3, Train Accuracy: 93.10344827586206%, Test Accuracy: 89.79591836734694%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_656_level_3, Train Accuracy: 47.05882352941176%, Test Accuracy: 33.33333333333333%
# Training model...
# Created pipeline
# Fitted
# Model: class_662_level_3, Train Accuracy: 53.191489361702125%, Test Accuracy: 36.17021276595745%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_622_level_3, Train Accuracy: 86.27450980392157%, Test Accuracy: 100.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_623_level_3, Train Accuracy: 62.96296296296296%, Test Accuracy: 10.0%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_751_level_3, Train Accuracy: 77.5%, Test Accuracy: 76.25%
# Training model...
# Created pipeline
# Fitted
# Model: class_753_level_3, Train Accuracy: 91.17647058823529%, Test Accuracy: 75.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_752_level_3, Train Accuracy: 100.0%, Test Accuracy: 90.9090909090909%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_744_level_3, Train Accuracy: 83.87096774193549%, Test Accuracy: 90.47619047619048%
# Training model...
# Created pipeline
# Fitted
# Model: class_729_level_3, Train Accuracy: 94.11764705882352%, Test Accuracy: 83.33333333333334%
# Training model...
# Created pipeline
# Fitted
# Model: class_725_level_3, Train Accuracy: 60.0%, Test Accuracy: 33.33333333333333%
# Training model...
# Created pipeline
# Fitted
# Model: class_723_level_3, Train Accuracy: 98.30508474576271%, Test Accuracy: 70.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_728_level_3, Train Accuracy: 53.125%, Test Accuracy: 81.81818181818183%
# Training model...
# Created pipeline
# Fitted
# Model: class_727_level_3, Train Accuracy: 75.0%, Test Accuracy: 50.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_720_level_3, Train Accuracy: 62.745098039215684%, Test Accuracy: 33.33333333333333%
# Training model...
# Created pipeline
# Fitted
# Model: class_724_level_3, Train Accuracy: 100.0%, Test Accuracy: 35.714285714285715%
# Training model...
# Created pipeline
# Fitted
# Model: class_731_level_3, Train Accuracy: 96.29629629629629%, Test Accuracy: 47.368421052631575%
# Training model...
# Created pipeline
# Fitted
# Model: class_738_level_3, Train Accuracy: 100.0%, Test Accuracy: 33.33333333333333%
# Training model...
# Created pipeline
# Fitted
# Model: class_732_level_3, Train Accuracy: 91.80327868852459%, Test Accuracy: 95.23809523809523%
# Training model...
# Created pipeline
# Fitted
# Model: class_737_level_3, Train Accuracy: 83.33333333333334%, Test Accuracy: 33.33333333333333%
# Training model...
# Created pipeline
# Fitted
# Model: class_733_level_3, Train Accuracy: 66.66666666666666%, Test Accuracy: 50.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_730_level_3, Train Accuracy: 85.71428571428571%, Test Accuracy: 0.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_761_level_3, Train Accuracy: 79.38144329896907%, Test Accuracy: 78.46153846153847%
# Training model...
# Created pipeline
# Fitted
# Model: class_762_level_3, Train Accuracy: 82.75862068965517%, Test Accuracy: 80.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_217_level_3, Train Accuracy: 95.1219512195122%, Test Accuracy: 32.142857142857146%
# Training model...
# Created pipeline
# Fitted
# Model: class_212_level_3, Train Accuracy: 60.71428571428571%, Test Accuracy: 50.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_213_level_3, Train Accuracy: 79.62962962962963%, Test Accuracy: 50.0%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_215_level_3, Train Accuracy: 90.9090909090909%, Test Accuracy: 100.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_214_level_3, Train Accuracy: 62.96296296296296%, Test Accuracy: 40.0%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_226_level_3, Train Accuracy: 78.33333333333333%, Test Accuracy: 85.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_228_level_3, Train Accuracy: 60.0%, Test Accuracy: 62.5%
# Training model...
# Created pipeline
# Fitted
# Model: class_223_level_3, Train Accuracy: 97.10144927536231%, Test Accuracy: 70.83333333333334%
# Training model...
# Created pipeline
# Fitted
# Model: class_222_level_3, Train Accuracy: 65.78947368421053%, Test Accuracy: 84.61538461538461%
# Training model...
# Created pipeline
# Fitted
# Model: class_225_level_3, Train Accuracy: 42.857142857142854%, Test Accuracy: 25.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_224_level_3, Train Accuracy: 61.111111111111114%, Test Accuracy: 46.15384615384615%
# Training model...
# Created pipeline
# Fitted
# Model: class_221_level_3, Train Accuracy: 77.77777777777779%, Test Accuracy: 66.66666666666666%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_415_level_3, Train Accuracy: 72.17391304347827%, Test Accuracy: 79.48717948717949%
# Training model...
# Created pipeline
# Fitted
# Model: class_416_level_3, Train Accuracy: 62.03703703703704%, Test Accuracy: 52.77777777777778%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_421_level_3, Train Accuracy: 62.96296296296296%, Test Accuracy: 70.3125%
# Training model...
# Created pipeline
# Fitted
# Model: class_441_level_3, Train Accuracy: 82.85714285714286%, Test Accuracy: 68.57142857142857%
# Training model...
# Created pipeline
# Fitted
# Model: class_442_level_3, Train Accuracy: 80.0%, Test Accuracy: 100.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_401_level_3, Train Accuracy: 90.0%, Test Accuracy: 71.42857142857143%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_403_level_3, Train Accuracy: 57.446808510638306%, Test Accuracy: 62.5%
# Training model...
# Training model...
# Created pipeline
# Fitted
# Model: class_521_level_3, Train Accuracy: 87.5%, Test Accuracy: 100.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_525_level_3, Train Accuracy: 96.66666666666667%, Test Accuracy: 90.9090909090909%
# Training model...
# Created pipeline
# Fitted
# Model: class_524_level_3, Train Accuracy: 66.66666666666666%, Test Accuracy: 50.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_522_level_3, Train Accuracy: 66.66666666666666%, Test Accuracy: 33.33333333333333%
# Training model...
# Created pipeline
# Fitted
# Model: class_512_level_3, Train Accuracy: 100.0%, Test Accuracy: 0.0%
# Training model...
# Created pipeline
# Fitted
# Model: class_513_level_3, Train Accuracy: 50.0%, Test Accuracy: 66.66666666666666%
# Training model...
# Created pipeline
# Fitted
# Model: class_511_level_3, Train Accuracy: 66.66666666666666%, Test Accuracy: 50.0%

# %%
level_3_df # we can verify that every row has been trained on
# Out:
#                                   hash  \
# 0     0000773cb4875c8a442094365013263f
# 1     001af489878da488b65b079afe993c82
# 2     007c9fbb0bc78d8f32a3c0d17b93dcae
# 3     01dacff5876c21f148ff0c99b018126a
# 4     01f6d74cdea3fafd7bf77811860da078
# ...                                ...
# 8385  2d26ce8ed29ba40bf192919e69464ba8
# 8386  65f511cecdbe8b90fc4178c8af86aa28
# 8387  8b1e08790c2102d612baffe83263c37d
# 8388  c7cd950d6f10b0f32ed21e710de314f4
# 8389  f4741685f0b9fc3f97020a8519e53266
#
#                                                 content   noc level_0_label  \
# 0     housekeep aid clean assign hospit manner candi...  3414             3
# 1     covid test site grow fit duti prioriti safeti ...  3414             3
# 2     endoscop work locat hill look compani health h...  3414             3
# 3     recreationist time term care home passion pers...  3414             3
# 4     porter depart patient summari context patient ...  3414             3
# ...                                                 ...   ...           ...
# 8385  heritag specialist world lead purpos futur pro...  5112             5
# 8386  time compani descript provid custom marc shelf...  5111             5
# 8387  field locat base employ basi contract compens ...  5112             5
# 8388  head date locat compani univers depart time ti...  5112             5
# 8389  student inform opportun employ citi thunder mi...  5113             5
#
#      level_1_label level_2_label level_3_label
# 0               34           341          3414
# 1               34           341          3414
# 2               34           341          3414
# 3               34           341          3414
# 4               34           341          3414
# ...            ...           ...           ...
# 8385            51           511          5112
# 8386            51           511          5111
# 8387            51           511          5112
# 8388            51           511          5112
# 8389            51           511          5113
#
# [8390 rows x 7 columns]
